# %% [markdown]
# # Video: Implementing Retrieval-Augmented Generation
#
# This video shows how an existing language model with embedding support can be quickly used to implement retrieval-augmented generation.

# %% [markdown]
# Script: (faculty on screen)
# * Retrieval-augmented generation or RAG aims for a best of both worlds approach to text generation.
# * It has the extreme flexibility of language models.
# * And it uses document search based on the same language models to fetch relevant documents and provide relevant context to the language model for in-context learning.
# * This video will show you a basic RAG implementation that answers questions about recipes grounded by the recipes on my Bacon Powered Recipes site.

# %%
import json

import google.genai as genai
from google.genai import types
from google.colab import userdata
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

# %%
embedding_model_name = 'gemini-embedding-001'
model_name = 'gemini-2.0-flash'

# %%
recipes = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx704-examples/refs/heads/main/data/recipes.tsv.gz", sep="\t")
recipes = recipes.set_index("recipe_slug")
recipes = recipes[:1000]

# %%
recipes.head()
# Out:
#                                                                   recipe_title  \
# recipe_slug
# spiced-pear-and-walnut-salad                      Spiced Pear And Walnut Salad
# roasted-pear-and-butternut-squash-soup  Roasted Pear And Butternut Squash Soup
# peach-clafoutis                                                Peach Clafoutis
# plum-clafoutis                                                  Plum Clafoutis
# pear                                                                      Pear
#
#                                                                       recipe_introduction  \
# recipe_slug
# spiced-pear-and-walnut-salad            Spiced pear and walnut salad is a delicious an...
# roasted-pear-and-butternut-squash-soup  Roasted pear and butternut squash soup is a cr...
# peach-clafoutis                         Peach clafoutis is a classic French dessert th...
# plum-clafoutis                          Plum clafoutis is a classic French dessert mad...
# pear                                    Pears are a sweet and juicy fruit that come in...
#
#                                                                        recipe_ingredients  \
# recipe_slug
# spiced-pear-and-walnut-salad            ["2 ripe pears, thinly sliced", "4 cups mixed ...
# roasted-pear-and-butternut-squash-soup  ["2 medium-sized butternut squash, peeled and ...
# peach-clafoutis                         ["4 ripe peaches, peeled and sliced", "3 eggs"...
# plum-clafoutis                          ["4-5 ripe plums, pitted and sliced", "3 eggs"...
# pear                                    ["1 sheet of puff pastry", "2 ripe pears, peel...
#
#                                                                       recipe_instructions  \
# recipe_slug
# spiced-pear-and-walnut-salad            ["In a small bowl, whisk together the olive oi...
# roasted-pear-and-butternut-squash-soup  ["Preheat the oven to 400°F.", "In a large bow...
# peach-clafoutis                         ["Preheat the oven to 375°F.", "Grease a 9-inc...
# plum-clafoutis                          ["Preheat the oven to 375°F (190°C) and butter...
# pear                                    ["Preheat the oven to 400°F.", "Roll out the p...
#
#                                        recipe_conclusion  \
# recipe_slug
# spiced-pear-and-walnut-salad                          \N
# roasted-pear-and-butternut-squash-soup                \N
# peach-clafoutis                                       \N
# plum-clafoutis                                        \N
# pear                                                  \N
#
#                                                                      recipe_related_slugs  \
# recipe_slug
# spiced-pear-and-walnut-salad            ["pear-and-blue-cheese-salad", "walnut-and-cra...
# roasted-pear-and-butternut-squash-soup  ["roasted-butternut-squash-and-apple-soup", "p...
# peach-clafoutis                         ["cherry-clafoutis", "blueberry-clafoutis", "a...
# plum-clafoutis                          ["cherry-clafoutis", "apple-clafoutis", "blueb...
# pear                                    ["pear-and-goat-cheese-salad", "pear-and-ginge...
#
#                                                             recipe_ts
# recipe_slug
# spiced-pear-and-walnut-salad            2023-06-17 22:10:35.744536+00
# roasted-pear-and-butternut-squash-soup  2023-06-17 22:10:46.428069+00
# peach-clafoutis                          2023-06-17 19:05:50.44248+00
# plum-clafoutis                          2023-06-17 19:05:42.705122+00
# pear                                    2023-06-17 22:11:13.760378+00

# %%
raw_embeddings = {}

# %%
recipe_embeddings = {}

# %%
def get_embedding(text):
    if text in raw_embeddings:
        return raw_embeddings[text]
    response = client.models.embed_content(model=embedding_model_name,
                                           contents=text)

    raw_embeddings[text] = np.array(response.embeddings[0].values)
    return raw_embeddings[text]

# %%
def save_recipe_embedding(recipe_tuple):
    recipe_slug = recipe_tuple.Index
    if recipe_slug in recipe_embeddings:
        return

    embedding = get_embedding(recipe_tuple.recipe_introduction)
    recipe_embeddings[recipe_slug] = embedding

# %%
for r in recipes.itertuples():
    save_recipe_embedding(r)

# %%
def get_response(contents):
    response = client.models.generate_content(model=model_name,
                                              contents=contents)
    return response.text

# %% [markdown]
# Script:
# * I've already loaded the Google genai modules and fetched embeddings for a thousand recipes.

# %%
query = "What ingredients are common in dessert recipes?"

# %% [markdown]
# Script:
# * I am going to ask this question, "What ingredients are common in dessert recipes?".
# * Without context, I expect a very generic answer to this question.

# %%
print(get_response(query))
# Out:
# Dessert recipes commonly include a range of ingredients that contribute to their sweetness, texture, and flavor. Here's a breakdown of some of the most common ones:
#
# **Sweeteners:**
#
# *   **Sugar:** The foundation of most desserts. Comes in various forms like granulated, powdered (icing), brown, and caster sugar (superfine). Each has a different texture and molasses content, affecting the final product.
# *   **Honey:** A natural sweetener that adds a distinct flavor.
# *   **Maple Syrup:** Another natural sweetener, offering a unique flavor profile.
# *   **Corn Syrup:** Used for its texture-enhancing properties, often in candies and icings.
# *   **Molasses:** A byproduct of sugar production, providing a rich, dark flavor.
# *   **Other Syrups:** Agave, rice malt syrup, etc., used as alternative sweeteners.
#
# **Fats:**
#
# *   **Butter:** Adds richness, flavor, and tenderness.
# *   **Oil:** Provides moisture and a tender crumb. Often used in cakes and quick breads.
# *   **Shortening:** Offers a neutral flavor and creates a very tender texture, especially in pie crusts.
# *   **Cream:** Contributes richness and moisture. Used in whipped cream, ice cream, and sauces.
# *   **Coconut Oil:** Adds a distinct coconut flavor and moisture.
# *   **Nuts:** Provide fat, texture, and flavor.
#
# **Flour:**
#
# *   **All-Purpose Flour:** The most common type of flour for baking.
# *   **Cake Flour:** Has a lower protein content, resulting in a tender crumb.
# *   **Bread Flour:** Has a higher protein content, creating a chewier texture (less common in desserts, but sometimes used).
# *   **Gluten-Free Flours:** Almond flour, rice flour, tapioca flour, etc., are used in gluten-free desserts.
#
# **Liquids:**
#
# *   **Milk:** Adds moisture and richness.
# *   **Water:** Used to hydrate ingredients and create the right consistency.
# *   **Eggs:** Bind ingredients, add richness, and contribute to structure.
# *   **Juice:** Adds flavor and moisture, often in fruit-based desserts.
# *   **Coffee/Espresso:** Used for flavor, especially in chocolate desserts.
# *   **Extracts and Liqueurs:** Add concentrated flavor (vanilla extract is a classic).
#
# **Leavening Agents:**
#
# *   **Baking Powder:** A chemical leavening agent that requires both an acid and a base to create carbon dioxide, which makes baked goods rise.
# *   **Baking Soda:** Another chemical leavening agent that requires an acidic ingredient (like buttermilk or lemon juice) to activate.
# *   **Yeast:** A biological leavening agent that ferments sugar to produce carbon dioxide. Used in breads and some cakes.
#
# **Flavorings:**
#
# *   **Vanilla Extract:** A staple in most dessert recipes.
# *   **Chocolate:** In various forms (chips, cocoa powder, melted), a very popular flavoring.
# *   **Fruits:** Fresh, frozen, dried, or canned. Add sweetness, flavor, and moisture.
# *   **Spices:** Cinnamon, nutmeg, ginger, cloves, etc., add warmth and complexity.
# *   **Nuts:** Almonds, walnuts, pecans, etc., contribute flavor and texture.
# *   **Zest:** Lemon, orange, or lime zest adds bright citrus flavor.
# *   **Salt:** Enhances the flavors of other ingredients.
#
# **Other Common Ingredients:**
#
# *   **Eggs:** They can act as binders, add richness, or leaven depending on how they are used.
# *   **Chocolate chips:** Semisweet, milk chocolate, white chocolate or other flavors.
# *   **Cornstarch:** A thickener, often used in puddings, sauces, and fruit fillings.
# *   **Gelatin:** A gelling agent used in jellies, mousses, and other desserts.
# *   **Pectin:** A gelling agent found in fruits, used to make jams and jellies.
#
# This list is not exhaustive, but it covers many of the core ingredients you'll find in a wide range of dessert recipes. The specific ingredients used will depend on the type of dessert you're making.

# %% [markdown]
# Script:
# * As you can see, the response was totally generic.
# * It is not specific at all to the recipes at Bacon Powered.
# * Let's get a list of recipes that might be useful for this question using the embeddings to find relevant documents.

# %%
def search_recipes(query):
    query_embedding = get_embedding(query)
    candidates = list(recipe_embeddings.keys())
    candidates.sort(key=lambda x: np.linalg.norm(recipe_embeddings[x]- query_embedding))
    return candidates[:10]

search_recipes(query)
# Out:
# ['chocolate-brownies',
#  'cheesecake',
#  'apple-crumble',
#  'blondie-bars',
#  'chocolate-mousse',
#  'pancakes',
#  'fudge',
#  'strawberry-tart',
#  'apple-crisp',
#  'coconut-cream-pie']

# %% [markdown]
# Script:
# * These 10 recipes all sound relevant to desserts except for pancakes.
# * That's a bit context dependent - are they stacked with fruit and whipped cream?
# * The language model will have to decide whether to include them.
# * How do we use all these recipes to improve the answer to our question?

# %%
def get_rag_prompt(query):
    rag_prompt = []
    rag_prompt.append(f"QUESTION: {query}\n\n")
    for recipe_slug in search_recipes(query):
        recipe = recipes.loc[recipe_slug]
        rag_prompt.append(f"RELEVANT RECIPE: {recipe.recipe_title}\n\n")
        rag_prompt.append(recipe.recipe_introduction)
        rag_prompt.append("\n\n")
        rag_prompt.append("Ingredients:\n")
        for ingredient in json.loads(recipe.recipe_ingredients):
            rag_prompt.append(f"* {ingredient}\n\n")
        rag_prompt.append("Instructions:\n")
        for instruction in json.loads(recipe.recipe_instructions):
            rag_prompt.append(f"* {instruction}\n\n")
        rag_prompt.append("\n\n")

    rag_prompt.append(f"QUESTION: {query}\n\n")
    rag_prompt.append(f"ANSWER: ")
    rag_prompt = "".join(rag_prompt)

    return rag_prompt

# %% [markdown]
# Script:
# * I designed this prompt to start with the question, list all the recipes including their introduction, ingredients list, and instructions.
# * Then I repeated the question, and added a prompt for the answer.
# * Why repeat the question?
# * Some research has shown that different queries work better with the question before context and some work better with the question after context, and repeating the question before and after tends to be as good or better than correctly guessing before or after.
# * We don't have any scientifically grounded rules at this point, and the answers vary from model to model and as the models improve.
# * Similarly, I included the recipes' introductions, ingredients, and instructions pretending that I did not know that the question was just about ingredients.
# * This makes this prompt structure more generally useful, and it would defeat the point of having the model figure out what was important if I had to pick and choose the data per question.
# * Let's look at the generated prompt now.

# %%
rag_prompt = get_rag_prompt(query)
print(rag_prompt)
# Out:
# QUESTION: What ingredients are common in dessert recipes?
#
# RELEVANT RECIPE: Chocolate Brownies
#
# Chocolate brownies are a classic dessert that are loved by many. They are a rich and decadent treat that are perfect for satisfying a sweet tooth. Brownies are typically made with cocoa powder, sugar, flour, eggs, and butter, and can be customized with additional ingredients such as nuts, chocolate chips, or frosting. They are typically baked in a square or rectangular pan and cut into individual servings.
#
# Ingredients:
# * 1 cup unsalted butter
#
# * 2 1/4 cups granulated sugar
#
# * 4 large eggs
#
# * 1 1/4 cups cocoa powder
#
# * 1 teaspoon salt
#
# * 1 teaspoon baking powder
#
# * 1 teaspoon vanilla extract
#
# * 1 1/2 cups all-purpose flour
#
# * 1 cup chocolate chips
#
# Instructions:
# * Preheat the oven to 350°F and grease a 9x13 inch baking pan.
#
# * In a large mixing bowl, melt the butter in the microwave or on the stove.
#
# * Add the sugar to the melted butter and stir until well combined.
#
# * Add the eggs one at a time, stirring well after each addition.
#
# * Add the cocoa powder, salt, baking powder, and vanilla extract to the bowl and stir until well combined.
#
# * Add the flour to the bowl and stir until just combined.
#
# * Fold in the chocolate chips.
#
# * Pour the batter into the prepared baking pan and smooth out the top.
#
# * Bake for 25-30 minutes, or until a toothpick inserted into the center comes out clean.
#
# * Allow the brownies to cool in the pan for 10-15 minutes before slicing and serving.
#
#
#
# RELEVANT RECIPE: Cheesecake
#
# Cheesecake is a rich and creamy dessert made with a graham cracker crust and a smooth, velvety filling made from cream cheese, sugar, and eggs. It can be flavored with a variety of ingredients such as vanilla, chocolate, or fruit, and is often topped with whipped cream or fruit compote.
#
# Ingredients:
# * 2 cups graham cracker crumbs
#
# * 1/2 cup unsalted butter, melted
#
# * 4 (8 oz) packages cream cheese, softened
#
# * 1 1/4 cups granulated sugar
#
# * 4 large eggs
#
# * 1 tsp vanilla extract
#
# * 1/4 cup all-purpose flour
#
# * 1/2 cup sour cream
#
# Instructions:
# * Preheat oven to 325°F. Grease a 9-inch springform pan.
#
# * In a medium bowl, mix together graham cracker crumbs and melted butter. Press mixture into the bottom of the prepared pan.
#
# * In a large bowl, beat cream cheese and sugar until smooth. Add eggs one at a time, beating well after each addition. Stir in vanilla extract.
#
# * Gradually add flour and sour cream, mixing until just combined.
#
# * Pour mixture over the crust in the prepared pan.
#
# * Bake for 50-60 minutes, or until the center is almost set.
#
# * Allow cheesecake to cool to room temperature, then refrigerate for at least 4 hours or overnight.
#
# * Serve chilled, topped with whipped cream or fruit compote.
#
#
#
# RELEVANT RECIPE: Apple Crumble
#
# Apple crumble is a classic dessert made with baked apples topped with a crispy, buttery crumble made of flour, sugar, and butter. The warm and comforting dessert is often served with a scoop of vanilla ice cream or a dollop of whipped cream.
#
# Ingredients:
# * 6 medium-sized apples, peeled and sliced
#
# * 1/2 cup all-purpose flour
#
# * 1/2 cup rolled oats
#
# * 1/2 cup brown sugar
#
# * 1/2 cup unsalted butter, softened
#
# * 1 tsp cinnamon
#
# * 1/4 tsp nutmeg
#
# * 1/4 tsp salt
#
# Instructions:
# * Preheat the oven to 375°F.
#
# * In a large bowl, mix together the sliced apples, cinnamon, nutmeg, and salt.
#
# * In a separate bowl, mix together the flour, rolled oats, brown sugar, and softened butter until it forms a crumbly mixture.
#
# * Pour the apple mixture into a baking dish and spread it out evenly.
#
# * Sprinkle the crumble mixture over the top of the apples.
#
# * Bake for 35-40 minutes, or until the top is golden brown and the apples are tender.
#
# * Serve warm with a scoop of vanilla ice cream or a dollop of whipped cream.
#
#
#
# RELEVANT RECIPE: Blondie Bars
#
# Blondie bars are a delicious dessert that are similar to brownies, but made with brown sugar instead of cocoa powder. They have a rich, buttery flavor and a chewy texture that is sure to satisfy any sweet tooth. Blondie bars can be customized with a variety of mix-ins, such as chocolate chips, nuts, or dried fruit, to create a unique and tasty treat.
#
# Ingredients:
# * 1 cup unsalted butter, melted
#
# * 2 cups light brown sugar
#
# * 2 large eggs
#
# * 2 teaspoons vanilla extract
#
# * 2 cups all-purpose flour
#
# * 1 teaspoon baking powder
#
# * 1/2 teaspoon salt
#
# * 1 cup mix-ins (chocolate chips, nuts, dried fruit, etc.)
#
# Instructions:
# * Preheat the oven to 350°F and line a 9x13 inch baking pan with parchment paper.
#
# * In a large mixing bowl, whisk together the melted butter and brown sugar until well combined.
#
# * Add the eggs and vanilla extract to the bowl and whisk until smooth.
#
# * In a separate bowl, whisk together the flour, baking powder, and salt.
#
# * Gradually add the dry ingredients to the wet ingredients, stirring until just combined.
#
# * Fold in the mix-ins of your choice.
#
# * Pour the batter into the prepared baking pan and smooth out the top with a spatula.
#
# * Bake for 25-30 minutes, or until the edges are golden brown and a toothpick inserted into the center comes out clean.
#
# * Allow the blondie bars to cool in the pan for 10-15 minutes before slicing and serving.
#
#
#
# RELEVANT RECIPE: Chocolate Mousse
#
# Chocolate mousse is a rich and decadent dessert made from whipped cream, egg yolks, and melted chocolate. The mixture is then chilled until it sets into a light and airy texture that melts in your mouth. It's the perfect dessert for any chocolate lover.
#
# Ingredients:
# * 8 oz. semisweet chocolate, chopped
#
# * 1/4 cup unsalted butter
#
# * 4 large eggs, separated
#
# * 1/4 cup granulated sugar
#
# * 1/2 cup heavy cream
#
# * 1 tsp. vanilla extract
#
# * Pinch of salt
#
# Instructions:
# * Melt the chocolate and butter in a double boiler or microwave, stirring occasionally until smooth. Set aside to cool slightly.
#
# * In a large bowl, beat the egg yolks and sugar until pale and thick.
#
# * In a separate bowl, beat the egg whites and salt until stiff peaks form.
#
# * In another bowl, whip the heavy cream and vanilla until soft peaks form.
#
# * Fold the melted chocolate into the egg yolk mixture until well combined.
#
# * Gently fold in the whipped cream, followed by the egg whites, until no white streaks remain.
#
# * Spoon the mixture into individual serving dishes and chill for at least 2 hours before serving.
#
#
#
# RELEVANT RECIPE: Pancakes
#
# Pancakes are a classic breakfast dish made from a simple batter of flour, eggs, milk, and baking powder. They are typically cooked on a griddle or in a frying pan until golden brown and fluffy. Pancakes can be served with a variety of toppings, such as butter, syrup, fruit, or whipped cream, making them a versatile and delicious breakfast option.
#
# Ingredients:
# * 1 1/2 cups all-purpose flour
#
# * 3 1/2 teaspoons baking powder
#
# * 1 teaspoon salt
#
# * 1 tablespoon white sugar
#
# * 1 1/4 cups milk
#
# * 1 egg
#
# * 3 tablespoons butter, melted
#
# Instructions:
# * In a large mixing bowl, combine the flour, baking powder, salt, and sugar.
#
# * In a separate bowl, whisk together the milk, egg, and melted butter.
#
# * Pour the wet ingredients into the dry ingredients and stir until just combined. Do not overmix.
#
# * Heat a non-stick griddle or frying pan over medium heat.
#
# * Using a 1/4 cup measuring cup, pour the batter onto the griddle or pan.
#
# * Cook until bubbles form on the surface of the pancake and the edges start to look dry, then flip and cook for an additional 1-2 minutes.
#
# * Serve hot with your favorite toppings.
#
#
#
# RELEVANT RECIPE: Fudge
#
# Fudge is a rich and creamy confectionery treat that is loved by many for its smooth texture and indulgent flavor. It is typically made by combining sugar, butter, milk, and chocolate, which are heated and then cooled to create a soft and chewy consistency. Fudge can be enjoyed in various flavors, such as classic chocolate, peanut butter, or even with added nuts or fruits. It is often cut into small squares and makes for a delightful homemade gift or a sweet treat to satisfy any sweet tooth.
#
# Ingredients:
# * 2 cups granulated sugar
#
# * 1 cup unsalted butter
#
# * 1 cup whole milk
#
# * 1 teaspoon vanilla extract
#
# * 2 cups semisweet chocolate chips
#
# * Optional: 1 cup chopped nuts (e.g., walnuts, pecans)
#
# Instructions:
# * Grease an 8x8-inch baking dish and set aside.
#
# * In a large saucepan, combine the sugar, butter, and milk over medium heat. Stir continuously until the mixture comes to a boil.
#
# * Once boiling, reduce the heat to low and continue stirring for about 5 minutes until the mixture thickens slightly.
#
# * Remove the saucepan from heat and add the vanilla extract and chocolate chips. Stir until the chocolate chips are completely melted and the mixture is smooth.
#
# * If desired, fold in the chopped nuts.
#
# * Pour the fudge mixture into the prepared baking dish and spread it evenly.
#
# * Allow the fudge to cool at room temperature for about 2 hours, then refrigerate for an additional 2 hours or until firm.
#
# * Once firm, cut the fudge into small squares and serve.
#
#
#
# RELEVANT RECIPE: Strawberry Tart
#
# Strawberry tart is a delicious dessert that consists of a buttery crust filled with a creamy custard and topped with fresh strawberries. The crust is usually made with flour, sugar, butter, and egg yolks, while the custard is made with milk, sugar, egg yolks, and vanilla extract. The strawberries are arranged on top of the custard in a beautiful pattern, and the tart is then chilled until ready to serve.
#
# Ingredients:
# * 1 1/2 cups all-purpose flour
#
# * 1/4 cup granulated sugar
#
# * 1/2 cup unsalted butter, cold and cubed
#
# * 2 egg yolks
#
# * 1/4 cup milk
#
# * 1/2 cup granulated sugar
#
# * 2 egg yolks
#
# * 1/4 cup cornstarch
#
# * 1 1/2 cups milk
#
# * 1 tsp vanilla extract
#
# * 2 cups fresh strawberries, hulled and sliced
#
# Instructions:
# * Preheat the oven to 350°F.
#
# * In a large bowl, whisk together the flour and sugar. Add the cold butter and use a pastry cutter or your fingers to mix until the mixture resembles coarse crumbs.
#
# * Add the egg yolks and milk and mix until the dough comes together.
#
# * Roll out the dough on a floured surface and transfer it to a 9-inch tart pan. Press the dough into the bottom and sides of the pan and trim any excess dough.
#
# * In a medium bowl, whisk together the sugar, egg yolks, and cornstarch until smooth.
#
# * In a saucepan, heat the milk over medium heat until it comes to a simmer. Slowly pour the milk into the egg mixture, whisking constantly.
#
# * Pour the mixture back into the saucepan and cook over medium heat, whisking constantly, until it thickens and comes to a boil.
#
# * Remove from heat and stir in the vanilla extract.
#
# * Pour the custard into the tart shell and smooth the top with a spatula.
#
# * Arrange the sliced strawberries on top of the custard in a decorative pattern.
#
# * Bake for 30-35 minutes, or until the crust is golden brown.
#
# * Let the tart cool to room temperature before serving.
#
#
#
# RELEVANT RECIPE: Apple Crisp
#
# Apple crisp is a classic dessert made with baked apples topped with a crispy, buttery crumble made of flour, sugar, and oats. The warm and comforting dish is often served with a scoop of vanilla ice cream or whipped cream.
#
# Ingredients:
# * 6 cups of sliced apples
#
# * 1/2 cup of all-purpose flour
#
# * 1/2 cup of rolled oats
#
# * 1/2 cup of brown sugar
#
# * 1/2 cup of unsalted butter, softened
#
# * 1 teaspoon of cinnamon
#
# * 1/4 teaspoon of nutmeg
#
# * 1/4 teaspoon of salt
#
# Instructions:
# * Preheat the oven to 375°F.
#
# * In a large bowl, mix together the sliced apples, cinnamon, nutmeg, and salt.
#
# * In a separate bowl, mix together the flour, rolled oats, brown sugar, and softened butter until it forms a crumbly mixture.
#
# * Pour the apple mixture into a 9x13 inch baking dish.
#
# * Sprinkle the crumble mixture over the top of the apples.
#
# * Bake for 40-45 minutes, or until the top is golden brown and the apples are tender.
#
# * Serve warm with a scoop of vanilla ice cream or whipped cream.
#
#
#
# RELEVANT RECIPE: Coconut Cream Pie
#
# Coconut cream pie is a classic dessert that features a flaky pie crust filled with a rich and creamy coconut custard. The custard is made with coconut milk, sugar, eggs, and cornstarch, and is flavored with vanilla extract and shredded coconut. The pie is then topped with whipped cream and more shredded coconut for a deliciously sweet and tropical treat.
#
# Ingredients:
# * 1 pre-made pie crust
#
# * 1 can (13.5 oz) coconut milk
#
# * 1 cup heavy cream
#
# * 3/4 cup granulated sugar
#
# * 1/4 cup cornstarch
#
# * 4 egg yolks
#
# * 1 tsp vanilla extract
#
# * 1 cup shredded coconut, plus more for topping
#
# * Whipped cream, for topping
#
# Instructions:
# * Preheat oven to 375°F.
#
# * Roll out the pie crust and place it in a 9-inch pie dish. Trim the edges and prick the bottom with a fork.
#
# * Bake the crust for 10-12 minutes, or until lightly golden. Let cool.
#
# * In a medium saucepan, whisk together the coconut milk, heavy cream, sugar, cornstarch, and egg yolks.
#
# * Cook the mixture over medium heat, whisking constantly, until it thickens and comes to a boil.
#
# * Remove from heat and stir in the vanilla extract and shredded coconut.
#
# * Pour the custard into the cooled pie crust and smooth out the top.
#
# * Chill the pie in the refrigerator for at least 2 hours, or until set.
#
# * Before serving, top the pie with whipped cream and more shredded coconut.
#
#
#
# QUESTION: What ingredients are common in dessert recipes?
#
# ANSWER:

# %% [markdown]
# Script:
# * That's a lot of text.
# * I bet the API providers charging for tokens love these long RAG queries.
# * Implementers still love this setup though because it improves the quality a lot.
# * Language models are getting a lot smarter, but they won't know about companies internal documents and rules unless we share them.
# * How did this prompt perform?

# %%
print(get_response(rag_prompt))
# Out:
# Based on the provided recipes, common ingredients in dessert recipes include:
#
# *   **Flour:** All-purpose flour is used in most of the listed recipes.
# *   **Sugar:** Both granulated sugar and brown sugar appear frequently.
# *   **Butter:** Unsalted butter is a very common ingredient.
# *   **Eggs:** Used in many desserts for richness and binding.
# *   **Vanilla extract:** A common flavoring agent.
# *   **Milk/Cream:** Used in many desserts for moisture and richness.
# *   **Chocolate:** Chocolate chips, cocoa powder, and semisweet chocolate are common.
# *   **Baking powder:** Used as a leavening agent in some recipes.
# *   **Salt:** Used to enhance flavors.
#
# Other ingredients that appear in multiple desserts:
#
# *   **Fruit:** Apples, strawberries
# *   **Oats:** Rolled oats
# *   **Nuts:** Chopped nuts,
# *   **Coconut:** Shredded coconut
# *   **Cream Cheese:** Used in cheesecake

# %% [markdown]
# Script:
# * That's a lot more specific to the provided recipes from my site.
# * For corporate use cases, this specificity is important.

# %% [markdown]
# Script: (faculty on screen)
# * Retrieval augmented generation is a great way to improve the accuracy and relevance of generated text.
# * New language models need less help to be generally correct now, but retrieving context still helps a lot in being situationally correct.
